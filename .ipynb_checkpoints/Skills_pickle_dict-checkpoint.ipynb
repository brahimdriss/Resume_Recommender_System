# %%
import os
import numpy as np
import pickle

dict = {}

for filename in os.listdir("Dicts"):
    if filename.endswith(".npy"):
        a = np.load("Dicts/"+filename)
        a = np.append(a,filename[:-15])
        dict[filename[:-15]]=[a]

# %%
dict
# Out:
# {'angular': [array(['angular-cli', 'angular js 2', 'angular', 'angular4', 'angularjs2',
#          'angular 2', 'angularjs (notions)', 'angular 4/springboot',
#          'angular 5', 'angular6', 'angular7', 'angular  4', 'angular 2+',
#          'angular cli', 'angular2/4/5', 'angularsjs', 'angular js 1.x',
#          'angularjs 1.x', 'angular 2/4/5/6', 'angular 7', 'angular 5/8',
#          'angula 4', 'nodejs, angularjs', 'angular8', 'angular 5/6',
#          'angular 4', 'angularjs4', 'angular4,', 'angular 2-4', 'angularj',
#          'angular.js', 'angular 6', 'angularjs 2', 'angular 4+',
#          'angular 5,6', 'angular5', 'angula', 'angluar js', 'angular2 +',
#          'angular 6+', 'angularjs,bootstrap', 'angularjs', 'angular js2',
#          'angular 2 et 4', 'angular2', 'angularjs 4', 'angular materia',
#          'angular 5/6/7', 'angular  2', 'angular 8', 'angular material',
#          'angular 2/4', 'angularjs 1 & 2', 'angular2-cli', 'angualr 4',
#          'angular 6 ,angular js', 'anglais', 'angulair js', 'angular ts',
#          'angular2+', 'angularjs 1', 'angular'], dtype='<U21')],
#  'AWS': [array(['aws iot', 'aws ecs', 'amazon sqs', 'amazon kinesis', 'amazon sns',
#          'amazon ebs', 'amazon ec2', 'aws kms', 'aws s3',
#          'amazon web service', 'amazon ses', 'amazon web services, docker',
#          'amazon vpc', 'aws core services', 'amazon web services (aws)',
#          'amazon ecs', 'AWS'], dtype='<U27')],
#  'C++': [array(['c/c++', 'c c++', 'dev c++', 'c / c++', 'dev-c++', 'c++/qt',
#          'c/c+ +', 'qt c++', 'devc++', 'c,c++', 'c++/c#', 'c, c++', 'c+',
#          'c++17', 'c\\c++', 'c ++', 'C++'], dtype='<U7')],
#  'CMS': [array(['conception wordpress', 'typo3', 'wordpress developer',
#          'cms:wordpress', 'cms : wordpress', 'joomla!', 'drupal 7',
#          'drupal8', 'drupal7', 'drupal 6', 'cms joomla', 'wordp',
#          'cms: wordpress', 'drupal 8', 'wordpress design', 'drupal 6/7',
#          'wordpess', 'CMS'], dtype='<U20')],
#  'CSS': [array(['css 5', 'css( feuille de style)', 'cascading style sheets (css)',
#          'css 3', 'feuilles de style en cascade (css)', 'css2', 'css3',
#          'cascading style sheet (css)', 'CSS'], dtype='<U34')],
#  'Docker': [array(['docker-compose', 'doker', 'dokcer', 'docker compose',
#          'docker-compse', 'docker swarm', 'dock', 'Docker'], dtype='<U14')],
#  'Drupal': [array(['drupal 7', 'drupal8', 'drupal7', 'drupal 6', 'drupal 8',
#          'drupal 6/7', 'Drupal'], dtype='<U10')],
#  'ExpressJS': [array(['nodejs/express.js', 'express.js', 'expressjs', 'ExpressJS'],
#         dtype='<U17')],
#  'FunctionalDesign': [array(['analyse et conception de système', 'functional architecture',
#          'cadrage et pilotage fonctionnel', 'spécifications fonctionnelles',
#          'software design', 'spécification fonctionnelle',
#          'analyste fonctionnelle', 'functional testing',
#          'functional requirements', 'analyse fonctionnelle et technique',
#          'application design', 'analyse des points fonctionnels',
#          'solution design', 'functional analysis',
#          'architecutre fonctionnelle', 'architecture fonctionnelle',
#          'analyse fonctionelle', 'product design', 'FunctionalDesign'],
#         dtype='<U34')],
#  'GitLab': [array(['gitlabci', 'gitlab ci', 'gitlab-ci', 'gitlub', 'gitlab ci/cd',
#          'GitLab'], dtype='<U12')],
#  'GIT': [array(['github', 'git hub', 'GIT'], dtype='<U7')],
#  'HapiJS': [array(['hapi.js', 'HapiJS'], dtype='<U7')],
#  'HTML': [array(['hml5', 'html css', 'dhtmlx', 'html5', 'html5/php', 'html5/css',
#          'html 5', 'dhtml', 'css/html', 'xhtml', 'html/css', 'html4',
#          'htmlunit', 'htm5', 'xhtml/css', 'hmtl', 'HTML'], dtype='<U9')],
#  'java': [array(['rxjava', 'javaee', 'java 1.8', 'java/jee', 'java me', 'javabeans',
#          'java:jee', 'java /jee', 'javase', 'java jee', 'java2d',
#          'java rmi', 'java ee6', 'java se', 'javamail', 'java5', 'javasc',
#          'java fx', 'java se 8', 'rx java', 'javacript', 'java 7', 'java 6',
#          'java  8', 'java-j2ee', 'java8+', 'java8', 'java2', 'javafx',
#          'javajee', 'java/j2ee', 'java\\\u200bjee', 'rmi java', 'java j2ee',
#          'javarmi', 'core java', 'java  ee', 'javacc', 'java 8', 'javacard',
#          'ihm java', 'java card', 'java7', 'java se8', 'jaas', 'java j2se',
#          'javas', 'java bean', 'java ee', 'javafx2', 'java'], dtype='<U9')],
#  'jquery': [array(['ajax/jquery', 'jquerymobile', 'jequery', 'jquery mobile',
#          'jquery booklet', 'jquery ajax', 'jqeury', 'jquery ui',
#          'jquery 3.2', 'jquey', 'jqu', 'jquery easy ui', 'juniper',
#          'jquerry', 'jquery'], dtype='<U14')],
#  'KoaJS': [array(['koa.js', 'KoaJS'], dtype='<U6')],
#  'MongoDB': [array(['mongobd', 'mongo', 'mongodb expert', 'mogodb', 'nosql( mongodb)',
#          'mongodb 3.4', 'mongo db', 'mangodb', 'MongoDB'], dtype='<U15')],
#  'MVC': [array(['mvc 5', 'mvc3', 'mvc2', 'mvc 4/5', 'puremvc', 'mockmvc', 'mvc4',
#          'mvc 2/3', 'mvc 2', 'model-view-controller (mvc)', 'MVC'],
#         dtype='<U27')],
#  'MySQL': [array(['mysqli', 'php - mysql', 'mysql 5', 'my sql', 'php/mysql',
#          'mysql 4/5', 'mysq', 'mysql 4.x', 'sgbd mysql', 'mysql 5.7',
#          'php5/mysql', 'MySQL'], dtype='<U11')],
#  'NodeJS': [array(['node', 'web nodejs', 'node.js', 'node js', 'NodeJS'], dtype='<U10')],
#  'PHP': [array(['php 5/7', 'php 7', 'amfphp', 'php4', 'cackphp', 'phpunit', 'php7',
#          'php3', 'php5', 'phpm', 'cakephp', 'phpbb', 'phpfox', 'fuelphp',
#          'php 5', 'easyphp', 'php oo', 'php5.x', 'php5/7', 'php4/5',
#          'Hypertext Preprocessor', 'PHP'], dtype='<U22')],
#  'ReactJS': [array(['react.js', 'react js', 'react.js / redux', 'react', 'reactj',
#          'ReactJS'], dtype='<U16')],
#  'REST': [array(['rest api', 'api rest.', 'restapi', 'restfull,', 'restfull',
#          'soap/rest', 'rest apis', 'restful', 'api rest', 'REST'],
#         dtype='<U9')],
#  'SASS': [array(['sass/css3', 'SASS'], dtype='<U9')],
#  'Scrum': [array(['scrumwise', 'agile scrum', 'scrumban', '2tup, scrum',
#          'scrummaster', 'icescrum', 'scrum agile', 'agile/scrum',
#          'scrum/agile', 'Scrum'], dtype='<U11')],
#  'SOA': [array(['soap ui', 'ws soap', 'soapui',
#          'architectures : soa, client/serveur,  n-tier',
#          'service-oriented architecture (soa)',
#          'archiecture orientée service (soa)',
#          'service oriented architecture design', 'soap',
#          'architecture orientée services (soa)', 'SOA'], dtype='<U44')],
#  'Spring': [array(['spring-rest', 'spring 4.2.1', 'spring-boot', 'spring se',
#          'spring test', 'spring cloud', 'spring batch', 'spring boot 2',
#          'spring ws', 'spring rest', 'spring data', 'spring/jee',
#          'spring dm', 'springcloud', 'spring tx', 'spring roo',
#          'j2ee spring', 'spring boot', 'spring  boot', 'springmvc', 'swing',
#          'springsource', 'spring-batch', 'spring 4', 'spring 4.1',
#          'spring ioc', 'spring webflow', 'ioc : spring', 'java spring',
#          'spring social', 'springboot', 'spring-data', 'spring di',
#          'spring mvc', 'spring core', 'spring aop', 'spring core,',
#          'jsf jsp spring', 'springsecurity', 'Spring'], dtype='<U14')],
#  'SVN': [array(['subversion svn', 'subversion, cvs', 'cvs, subversion, git',
#          'svn/git', 'subversion (svn)', 'SVN'], dtype='<U20')],
#  'Symfony': [array(['symfony 3.4', 'symphony2', 'symfony 1.4 & 2', 'synfony 2',
#          'symphony 2', 'symfony2.x', 'symfony1.4', 'symfonie', 'synphony2',
#          'symfony 2 et 3', 'synfony2', 'symfony 3.3', 'symfony 2 / 3',
#          'php symfony2', 'php symfony', 'symfony 1.4', 'symfony 3.0',
#          'symfony 2/3', 'symfony1.x', 'symfo', 'symfony 2', 'symfony2/3',
#          'symfony2', 'symfony 3', 'symfony 2/3/4', 'symfony 4',
#          'symphony 4.3', 'symfony4', 'symphony', 'symfony 4.1',
#          'php/symfony', 'symfony 3 et 4', 'symfony3', 'symfony_live',
#          'Symfony'], dtype='<U15')],
#  'TestScrum': [array(['ui testing', 'test agil', 'software testing', 'test planning',
#          'unit testing', 'test engineering', 'system testing',
#          'stress testing', 'web testing', 'agile testing', 'manual testing',
#          'selenium testing', 'TestScrum'], dtype='<U16')],
#  'WebPack': [array(['webpack2', 'WebPack'], dtype='<U8')]}

# %%
with open('skills_dict',"wb") as handle:
    pickle.dump(dict,handle)

# %%
with open('skills_dict',"rb") as handle:
    b = pickle.load(handle)
